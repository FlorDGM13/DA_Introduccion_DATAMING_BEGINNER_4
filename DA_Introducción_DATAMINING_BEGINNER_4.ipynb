# %% [markdown]
# <a href="https://colab.research.google.com/github/FlorDGM13/DA_Introduccion_DATAMING_BEGINNER_4/blob/main/DA_Introducci%C3%B3n_DATAMINING_BEGINNER_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA MINING

# %% [markdown]
# El data mining, tambien conocido como mineria de datos, es el proceso de extracion de patrones, conocimientos y correlaciones utiles a partir de grandes volumenes de datos. esto se logra mediante la aplicacionde tecnicas de analisis  de datos y algoritmo de aprendizaje automatico

# %% [markdown]
# ## CONCEPTOS BASICOS

# %% [markdown]
# * DATASET: Conjunto de datos recolectados y organizados para su análisis
# * ATRIBUTOS: Características o variables que describe los objetos del dataset
# * REGISTRO: Un conjunto de atributos que describen a un objeto en el dataset
# * CLASIFICACIÓN: Asignación de objetos a clases predefinidas en función de sus atributos
# * REGRESIÓN: Predicción de un valor numércio en función de los atributos de un objeto
# * AGRUPACIÓN: Dvisión de los objetos en grupos según sus satributos, de manera que los objetos en un grupo sean similares entre sií y diferentes a los objetos en otro grupos

# %% [markdown]
# PROCESO DE DATA MINING (CRISP-DM)
#
# * CRISP-DM (Cross- Insutry standard Process for Data Mining)es una metodología ampliamente utiizada que consta de las siguientes etapas:
#
# 1. Comprensión del negocio: Identficar y entender los objetivoc del negocio y las necesidades en términos de análisis de datos
#
# 2. Comprensión de los datos:Exploar, describir y evaluar la calida de los datos disponibles
#
# 3. Preparación de los datos: Limpieza, transformación y preprocesamiento de datos para su uso en al algoritmos de mineria de datos
#
# 4. Modelado: Selección y aplicación de algoritmos y técnicas de mineria de datos para construir modelos que describen o predigan patrones en los datos
#
# 5. Evaluación: Validar y evaluarlos modelos obtenidos para asegurar que cumplan con los objetivos del negocio
#
# 6. Implementación: desplegar los modelos en la organización y aplicarlos en la toma de desiones del negocio.

# %% [markdown]
# ## TÉCNICA PCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA

# %%
df = sns.load_dataset('iris')
df.iloc[:,:-1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pca_model = PCA(n_components=2)
df_pca = pca_model.fit_transform(df.iloc[:,:-1])
df_pca
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
#        [-2.46882007,  0.13095149],
# ...

# %%
plt.scatter(df_pca[:,0],df_pca[:,1], c=df['species'].astype('category').cat.codes)
plt.title('PCA')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()

# %% [markdown]
# ## TÉCNICA TRANSFORMACIÓN DE *VARIABLES*

# %%
sns.displot(data=df, x ='sepal_length', hue='species', kde=True)
plt.show()

# %%
#Transformación logaritmica
df["sepal_length_log"] = np.log(df["sepal_length"])
sns.displot(data=df, x ='sepal_length_log', hue='species', kde=True)
plt.show()

# %% [markdown]
# ## TÉCNICA NORMALIZACIÓN DE DATOS

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_log
# 0            1.629241
# 1            1.589235
# 2            1.547563
# 3            1.526056
# ...

# %%
std_scaler = StandardScaler()
df_std_scaler = std_scaler.fit_transform(df.iloc[:,:-2])
df_std_scaler
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
mm_scaler = MinMaxScaler()
df_normalized = mm_scaler.fit_transform(df.iloc[:,:-2])
df_normalized
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %% [markdown]
# ## TÉCNICA DE CORRELACIÓN (PEARSON)

# %%
from scipy.stats import pearsonr

# %%
#Calcular la correlación de pearson

correlacion, _ = pearsonr(df['sepal_length'], df['petal_length'])
print('La Correlación es: %.3f' % correlacion)
# Out:
# La Correlación es: 0.872

# %% [markdown]
# ## TÉCNICA DE ANALISIS DE CLUSTERS

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, random_state=42)
df['cluster'] = model.fit_predict(df.iloc[:,:-2])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_log  cluster
# 0            1.629241        1
# 1            1.589235        1
# 2            1.547563        1
# ...

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='cluster')
plt.show()

# %% [markdown]
# ## TÉCNICA Z-SCORE

# %%
#Calcular el Z-Scores
df["z_score_sepal_length"] = np.abs((df["sepal_length"] - df["sepal_length"].mean())/df["sepal_length"].std())
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_length_log  cluster  z_score_sepal_length
# 0            1.629241        1              0.897674
# ...

# %%
outliers = df[df["z_score_sepal_length"] > 2]
outliers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
#
#      sepal_length_log  cluster  z_score_sepal_length
# 105          2.028148        0              2.121409
# 117          2.041220        0              2.242172
# 118          2.041220        0              2.242172
# 122          2.041220        0              2.242172
# 131          2.066863        0              2.483699
# 135          2.041220        0              2.242172

# %%
sns.scatterplot(data=df, x='sepal_length', y='petal_length', hue='species')
sns.scatterplot(data=outliers, x='sepal_length', y='petal_length', color='red')
plt.show()
